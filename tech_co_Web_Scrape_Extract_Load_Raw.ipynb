# %%
pip install firecrawl-py pymysql
# Out:
# Requirement already satisfied: firecrawl-py in /usr/local/lib/python3.11/dist-packages (2.5.3)
# Requirement already satisfied: pymysql in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from firecrawl-py) (2.32.3)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from firecrawl-py) (1.1.0)
# Requirement already satisfied: websockets in /usr/local/lib/python3.11/dist-packages (from firecrawl-py) (15.0.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from firecrawl-py) (1.6.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from firecrawl-py) (2.11.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from firecrawl-py) (3.11.15)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->firecrawl-py) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->firecrawl-py) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->firecrawl-py) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->firecrawl-py) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->firecrawl-py) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->firecrawl-py) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->firecrawl-py) (1.20.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->firecrawl-py) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic->firecrawl-py) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->firecrawl-py) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->firecrawl-py) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->firecrawl-py) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->firecrawl-py) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->firecrawl-py) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->firecrawl-py) (2025.4.26)

# %%
from firecrawl import FirecrawlApp
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine

# %%
url = 'https://tech.co/news/best-ai-chatbots'

# %%
app = FirecrawlApp(api_key='fc-d2a7c7ffa9b54839a55229d8d768cf1a')

# %%
scrape_result = app.scrape_url(
    url=url,
    formats=['json'],
    json_options={
        'prompt': 'extract from the list of 13 chatbots, the chatbots name, best for, plan, createdBy, pros and cons.'
    }
)

# %%
scrape_result.json
# Out:
# {'chatbots': [{'name': 'ChatGPT',
#    'bestFor': 'Best AI chatbot overall (and best for image generation)',
#    'plan': 'Free plan: Yes',
#    'createdBy': 'OpenAI',
#    'pros': ['Powerful LLM',
#     'Regular Updates',
#     'Create your own GPTs',
#     'Very Scaleable',
#     'Large context window'],
#    'cons': ['GPT-4 Only on Plus plan',
#     'Sometimes crashes',
#     'Phone number required',
#     'Cut-off September 2022',
#     'No real-time internet access on the free plan']},
#   {'name': 'Gemini',
#    'bestFor': 'Best AI chatbot overall for creative tasks',
#    'plan': 'Free plan: Yes',
#    'createdBy': 'Google',
#    'pros': ['New LLM (Gemini)',
#     'Great at coding',
#     'Very quick & creative',
#     'Connected to internet',
#     'Free to use (for now)'],
#    'cons': ['Hallucinations common',
#     'No build-your-own chatbot tool (yet)',
#     'No customer support']},
#   {'name': 'Claude',
#    'bestFor': 'Best for large inputs/document review',
#    'plan': 'Paid plan: Yes',
#    'createdBy': 'Anthropic',
#    'pros': ['Industry-leading context window perfect for enterprise application',
#     'Claude Instant (lightweight)',
#     'Constitutional AI',
#     'Pay-per-token pricing for businesses',
#     'Welcoming interface'],
#    'cons': ['Not as powerful as ChatGPT',
#     'No way to make custom bots',
#     'No internet access in real-time']},
#   {'name': 'Grok',
#    'bestFor': 'Best for entertaining conversations',
#    'plan': 'Paid plan: No',
#    'createdBy': 'xAI',
#    'pros': ['Outperforms ChatGPT on some tests',
#     "Designed to be 'humorous'",
#     'Has real-time access to X network'],
#    'cons': ['Only available to X Premium+ subscribers',
#     'Only supports text inputs',
#     'Already being politicized']},
#   {'name': 'Writesonic',
#    'bestFor': 'Best for content creation',
#    'plan': 'Free plan: Yes',
#    'createdBy': 'Writesonic',
#    'pros': ['Huge range of additional tools',
#     'Great for businesses creating content',
#     'Build-your-own chatbot tool',
#     'Connected to the internet',
#     'Image generator'],
#    'cons': ["Pricey if you don't need content creation features",
#     'Lack of customization options',
#     'High costs for generating lots of words']},
#   {'name': 'Llama2.ai',
#    'bestFor': 'Best open source chatbot',
#    'plan': 'Free plan: Yes',
#    'createdBy': 'Meta (LLM)/ Replicate (Chatbot)',
#    'pros': ['Open source, so great for developers',
#     'Not as busy as ChatGPT/Bard',
#     'Run-time and token counter',
#     "'Temperature' adjuster"],
#    'cons': ["Not an 'official' Llama 2 chatbot",
#     'No internet access at present']},
#   {'name': 'Copilot',
#    'bestFor': 'Best chatbot + web search combo',
#    'plan': 'Free plan: Yes',
#    'createdBy': 'Microsoft',
#    'pros': ['Web results + chatbot answer provided',
#     "Cites website sources it's using",
#     'Adjustable conversation style',
#     'Image and audio inputs are available',
#     'GPT-4 access'],
#    'cons': ['2,000-word cap on queries',
#     "Sign-in required for 'longer conversations'"]},
#   {'name': 'Perplexity AI',
#    'bestFor': 'Best for Research',
#    'plan': 'Free plan: Yes',
#    'createdBy': 'Perplexity.ai',
#    'pros': ['Provides pre-set prompts',
#     'Great at source citing',
#     'Clean & simple interface',
#     "Interesting 'Discover' tab",
#     'Playground tool included'],
#    'cons': ['Can be slow to answer',
#     'Not suitable for coding',
#     'Pricey paid plan']},
#   {'name': 'Pi',
#    'bestFor': 'Best personal AI',
#    'plan': 'Free plan: Yes',
#    'createdBy': 'Inflection',
#    'pros': ['Friendly & safe',
#     'Straightforward interface',
#     'Very quick responses'],
#    'cons': ['Not as powerful as ChatGPT', 'No real business application']},
#   {'name': 'Personal AI',
#    'bestFor': 'Best personal assistant',
#    'plan': 'Free plan: Yes',
#    'createdBy': 'Human Labs Inc',
#    'pros': ['Highly customizable',
#     'Easy to train/edit',
#     'Lots of instructions'],
#    'cons': ['Long set-up time', 'Language model is small', 'Expensive plans']},
#   {'name': 'Poe',
#    'bestFor': 'Best chatbot aggregator',
#    'plan': 'Free plan: Yes',
#    'createdBy': 'Quora',
#    'pros': ['Access to all major chatbots',
#     'Android and iOS apps',
#     'Assistant chatbot included',
#     'You can make your own AI bot'],
#    'cons': ["Assistant isn't very advanced",
#     'Pricey paid plans needed to access the best language models and features']},
#   {'name': 'YouChat',
#    'bestFor': 'Best Microsoft Copilot alternative',
#    'plan': 'Free plan: Yes',
#    'createdBy': 'You.com',
#    'pros': ['Chatbot answer + web search',
#     "'Research' mode available",
#     'GPT-4 access (sign-in required)',
#     'Clear interface',
#     'Cites sources (usually)'],
#    'cons': ['Not as useful for coding/paraphrasing etc.',
#     'Free plan only has GPT-3 available']},
#   {'name': 'Character AI',
#    'bestFor': 'Great fun & generates images',
#    'plan': 'Free plan: Yes',
#    'createdBy': 'Character AI',
#    'pros': ['Some characters generate images',
#     'highly customizable',
#     'Users can make their own characters',
#     'You can use chatbots made by other people'],
#    'cons': ['Some data privacy concerns',
#     "Chatbots aren't very advanced",
#     'Not suitable for work tasks']}]}

# %%
chatbots = scrape_result.json

# %%
df = pd.json_normalize(df['chatbots'])

# %%
df
# Out:
#              name  ...                                               cons
# 0         ChatGPT  ...  [GPT-4 Only on Plus plan, Sometimes crashes, P...
# 1          Gemini  ...  [Hallucinations common, No build-your-own chat...
# 2          Claude  ...  [Not as powerful as ChatGPT, No way to make cu...
# 3            Grok  ...  [Only available to X Premium+ subscribers, Onl...
# 4      Writesonic  ...  [Pricey if you don't need content creation fea...
# 5       Llama2.ai  ...  [Not an 'official' Llama 2 chatbot, No interne...
# 6         Copilot  ...  [2,000-word cap on queries, Sign-in required f...
# 7   Perplexity AI  ...  [Can be slow to answer, Not suitable for codin...
# 8              Pi  ...  [Not as powerful as ChatGPT, No real business ...
# 9     Personal AI  ...  [Long set-up time, Language model is small, Ex...
# 10            Poe  ...  [Assistant isn't very advanced, Pricey paid pl...
# 11        YouChat  ...  [Not as useful for coding/paraphrasing etc., F...
# 12   Character AI  ...  [Some data privacy concerns, Chatbots aren't v...
#
# [13 rows x 6 columns]

# %%
user = 'postgres'
password = 'isba_4715'
host = 'isba-dev-02.cxcoakgsc7ha.us-east-1.rds.amazonaws.com'
port = 5432
database = 'postgres'


engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}')

# %%
df.to_sql(name= '13 Best Free and Paid AI Chatbots', con=engine, if_exists='replace', index=False)
# Out:
# 13
